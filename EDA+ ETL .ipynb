# %% [markdown]
# # Importing Necesseties

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('C:\\Users\\Dell\\Desktop\\Project_JobInTech\\Digital_factory_project\\01-Regroupe base 18-19 anonymat (S1, S2) V04012021.xlsx')

# %%
df.head(30)
# Out:
#     N° Nom étudiant      Niveau       Cycle Filière Etablissement     College  \
# 0    1         NNN1  2ème année      Master     G2I        SC. Po       HSPJS
# 1    2         NNN2  2ème année      Master     CIT           RBS  Management
# 2    3         NNN3  1ère année      Master     SCM           RBS  Management
# 3    4         NNN4  5ème année   Ingénieur      CI         ECINE          IA
# 4    5         NNN5  2ème année      Master     MRH           RBS  Management
# 5    6         NNN6  1ère année      Master     SCM           RBS  Management
# 6    7         NNN7  2ème année      Master     MKG           RBS  Management
# 7    8         NNN8  2ème année      Master     DAF          IEPJ       HSPJS
# 8    9         NNN9  1ère année      Master     CIT           RBS  Management
# 9   10        NNN10  2ème année      Master     SCM           RBS  Management
# 10  11        NNN11  4ème année   Ingénieur      CI           FIL          IA
# ...

# %% [markdown]
# # EDA + PRE-Proccessing

# %%
df.shape
# Out:
# (4007, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4007 entries, 0 to 4006
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   N°                        4007 non-null   int64
#  1   Nom étudiant              4006 non-null   object
#  2   Niveau                    4006 non-null   object
#  3   Cycle                     4007 non-null   object
#  4   Filière                   4007 non-null   object
#  5   Etablissement             4007 non-null   object
#  6   College                   4007 non-null   object
#  7   Moyenne S1                3936 non-null   object
#  8   Moyenne S2                3948 non-null   object
#  9   Moyenne                   3953 non-null   object
#  10  Decision jury             4007 non-null   object
#  11  Tranche                   3726 non-null   object
#  12  Classement                0 non-null      float64
# ...

# %%
df.describe()
# Out:
#                 N°  Classement  Mapp année bac  Mapp année UIR  Nb absences
# count  4007.000000         0.0     3939.000000     3981.000000  2153.000000
# mean   2004.000000         NaN     2015.678091     2016.734991    25.628425
# std    1156.865593         NaN        2.014915        1.286518    28.938811
# min       1.000000         NaN     2000.000000     2011.000000     1.000000
# 25%    1002.500000         NaN     2014.000000     2016.000000     8.000000
# 50%    2004.000000         NaN     2016.000000     2017.000000    16.000000
# 75%    3005.500000         NaN     2017.000000     2018.000000    33.000000
# max    4007.000000         NaN     2018.000000     2018.000000   301.000000

# %%
df.columns
# Out:
# Index(['N°', 'Nom étudiant', 'Niveau', 'Cycle', 'Filière', 'Etablissement',
#        'College', 'Moyenne S1', 'Moyenne S2', 'Moyenne', 'Decision jury',
#        'Tranche', 'Classement', 'Sexe', 'Nationalité', 'Date de naissance',
#        'Série bac', 'Mention bac', 'Moyenne bac', 'Année bac',
#        'Niveau accès UIR', 'Date inscription UIR', 'Mapp année bac',
#        'Mapp série bac (option)', 'Mapp série bac', 'Mapp série bac (domaine)',
#        'Mapp niveau acces', 'Mapp année UIR', 'Boursier', 'Mapp Jury',
#        'CSP Père', 'CSP Mère', 'Lycée origine', 'Système d'études', 'Région',
#        'Ville', 'Nb absences', 'Diplômés'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# N°                             0
# Nom étudiant                   1
# Niveau                         1
# Cycle                          0
# Filière                        0
# Etablissement                  0
# College                        0
# Moyenne S1                    71
# Moyenne S2                    59
# Moyenne                       54
# Decision jury                  0
# Tranche                      281
# Classement                  4007
# Sexe                           0
# Nationalité                   73
# Date de naissance             69
# Série bac                     90
# Mention bac                  132
# Moyenne bac                  896
# Année bac                     68
# Niveau accès UIR             104
# Date inscription UIR          26
# Mapp année bac                68
# Mapp série bac (option)       90
# Mapp série bac                90
# Mapp série bac (domaine)      90
# Mapp niveau acces            151
# Mapp année UIR                26
# ...

# %%
cdf = df.copy()

# %%
unique_nationalities = cdf['Nationalité'].unique()
print(unique_nationalities)
# Out:
# [nan 'Marocaine' 'MA' 'MAROCAINE' 'Camerounaise' 'TN' 'FR' 'Gabonnaise'
#  'Marocaine/Américaine' 'Française' 'CONGO' 'TD' 'USA' 'Congo' 'GA'
#  'Riyad Saudi arabia' "Côte D'ivoire" 'CI' 'Sénégal' 'Tunisienne'
#  'Malgache']

# %%
unique_nationalities = cdf['Nationalité'].value_counts()
print(unique_nationalities)
# Out:
# MA                      2584
# Marocaine               1316
# MAROCAINE                  9
# FR                         8
# Congo                      2
# Tunisienne                 1
# Sénégal                    1
# CI                         1
# Côte D'ivoire              1
# Riyad Saudi arabia         1
# GA                         1
# TD                         1
# USA                        1
# CONGO                      1
# Française                  1
# Marocaine/Américaine       1
# Gabonnaise                 1
# TN                         1
# Camerounaise               1
# Malgache                   1
# Name: Nationalité, dtype: int64

# %%
cdf['Nationalité'] = cdf['Nationalité'].replace(['Marocaine','MA', 'MAROCAINE', 'ci','TN','FR','GA','USA','TD','CONGO','Sénégal','Riyad Saudi arabia',"Côte D'ivoire",'CI'], ['Marocain(e)','Marocain(e)', 'Marocain(e)', 'Ivoirien','Tunisienne','Française','Gabonnaise','Américaine','Tchadiens','Congolais(e)','Sénégalais(e)'," l'Arabie saoudite",'Ivoirien','Ivoirien'])
cdf['Nationalité'].head(20)
# Out:
# 0             NaN
# 1     Marocain(e)
# 2     Marocain(e)
# 3     Marocain(e)
# 4     Marocain(e)
# 5     Marocain(e)
# 6     Marocain(e)
# 7     Marocain(e)
# 8     Marocain(e)
# 9     Marocain(e)
# 10    Marocain(e)
# 11    Marocain(e)
# 12    Marocain(e)
# 13    Marocain(e)
# 14    Marocain(e)
# 15    Marocain(e)
# 16    Marocain(e)
# 17    Marocain(e)
# 18    Marocain(e)
# 19    Marocain(e)
# Name: Nationalité, dtype: object

# %%
cdf['Nationalité'] = cdf.apply(lambda row: 'Marocaine' if row['Sexe'] == 'F' and row['Nationalité'] == 'Marocain(e)' else
                            'Marocain' if row['Sexe'] == 'M' and row['Nationalité'] == 'Marocain(e)' else
                            row['Nationalité'], axis=1)
cdf['Nationalité'].head(20)
# Out:
# 0           NaN
# 1      Marocain
# 2      Marocain
# 3      Marocain
# 4     Marocaine
# 5     Marocaine
# 6     Marocaine
# 7      Marocain
# 8      Marocain
# 9     Marocaine
# 10     Marocain
# 11     Marocain
# 12    Marocaine
# 13     Marocain
# 14     Marocain
# 15     Marocain
# 16     Marocain
# 17     Marocain
# 18     Marocain
# 19     Marocain
# Name: Nationalité, dtype: object

# %%
cdf = cdf.drop(columns=['Classement', 'Série bac', 'Année bac', 'Niveau accès UIR', 'Date inscription UIR'])

# %%
cdf = cdf.rename(columns={
    'Mapp année bac': 'Année bac',
    'Mapp série bac (option)': 'Option bac',
    'Mapp série bac': 'Série bac',
    'Mapp série bac (domaine)': 'Domaine bac',
    'Mapp niveau acces': 'Niveau accès UIR',
    'Mapp année UIR': 'Date inscription UIR',
    'Mapp Jury': 'Decision jury',
    'Decision jury': 'Decision jury detailed'
})

# %%
cdf['Date inscription UIR'] = cdf['Date inscription UIR'].apply(lambda x: 
    str(int(x)) + '/' + str(int(x) + 1) if isinstance(x, (int, float)) and not pd.isna(x) else 
    x if isinstance(x, str) and '-' in x else 
    str(int(x[:4])) + '/' + str(int(x[:4]) + 1) if isinstance(x, str) and len(x) == 4 else 
    x)

cdf['Année bac'] = cdf['Année bac'].apply(lambda x: 
    str(int(x)) + '/' + str(int(x) + 1) if isinstance(x, (int, float)) and not pd.isna(x) else 
    x)

# %%
print(cdf['Date inscription UIR'])
print(cdf['Année bac'])
# Out:
# 0             NaN
# 1       2016/2017
# 2       2018/2019
# 3       2014/2015
# 4       2017/2018
#           ...
# 4002          NaN
# 4003          NaN
# 4004          NaN
# 4005    2014/2015
# 4006    2014/2015
# Name: Date inscription UIR, Length: 4007, dtype: object
# 0             NaN
# 1       2011/2012
# 2       2011/2012
# 3       2012/2013
# 4       2012/2013
#           ...
# 4002          NaN
# 4003          NaN
# 4004          NaN
# 4005    2014/2015
# 4006    2014/2015
# Name: Année bac, Length: 4007, dtype: object

# %%
Mention_bac = cdf['Mention bac'].unique()
print(Mention_bac)
# Out:
# [nan 'Assez Bien' 'Bien' 'Passable' 'Très Bien' 'PASSABLE' 'A BIEN'
#  'TRES BIEN' '-' 'Très bien' 'Assez bien' 'BIEN' 'bien' 'passable'
#  'assez bien' 'très bien' 'A-BIEN' '14,12' 'Tres bien']

# %%
Mention_bac = cdf['Mention bac'].value_counts()
print(Mention_bac)
# Out:
# Bien          1259
# Assez Bien     784
# Passable       677
# Très Bien      403
# Assez bien     336
# Très bien      251
# bien            40
# PASSABLE        31
# assez bien      25
# A BIEN          20
# passable        18
# très bien       13
# BIEN             8
# -                3
# A-BIEN           3
# TRES BIEN        2
# 14,12            1
# Tres bien        1
# Name: Mention bac, dtype: int64

# %%
cdf['Mention bac'] = cdf['Mention bac'].replace(['Assez bien','Très bien','bien','PASSABLE','assez bien','A BIEN','passable','très bien','BIEN','A-BIEN','TRES BIEN','14,12','Tres bien','-'], ['Assez Bien','Très Bien','Bien','Passable','Assez Bien','Bien','Passable','Très Bien','Bien','Bien','Très Bien','Bien','Très Bien','Null'])
Mention_bac = cdf['Mention bac'].value_counts()
print(Mention_bac)
# Out:
# Bien          1331
# Assez Bien    1145
# Passable       726
# Très Bien      670
# Null             3
# Name: Mention bac, dtype: int64

# %%
Niveau_accès_UIR = cdf['Niveau accès UIR'].unique()
print(Niveau_accès_UIR)
# Out:
# [nan 'Licence' 'Baccalauréat' 'Bac+2' 'Bac+3' 'Bac+1']

# %%
Niveau_accès_UIR = cdf['Niveau accès UIR'].value_counts()
print(Niveau_accès_UIR)
# Out:
# Baccalauréat    3095
# Licence          669
# Bac+2             38
# Bac+1             34
# Bac+3             20
# Name: Niveau accès UIR, dtype: int64

# %%
#cdf['Niveau accès UIR'] = cdf['Niveau accès UIR'].replace(['Licence','baccalauréat','licence','Baccaluaréat','Baccaluréat','BAC+1','Baccalauréat+1','Baccalauréat +1','Baccalauréat+2','BAC +2/ CPGE','BAC+2','Bac +3','BAC+2 ENSAM','BAC+2 CPGE IBN GHAZI','BAC+2 CPGE UIR'], ['Bac+3','Baccalauréat','Bac+3','Baccalauréat','Baccalauréat','Bac+1','Bac+1','Bac+1','Bac+2','Bac+2','Bac+2','Bac+3','Bac+2','Bac+2','Bac+2'])
#Niveau_accès_UIR = cdf['Niveau accès UIR'].value_counts()
#print(Niveau_accès_UIR)

# %%
Decision_jury = cdf['Decision jury'].unique()
print(Decision_jury)
# Out:
# ['Non admis' 'Admis' 'Année blanche' 'Abandon' 'Exclu' 'Réorienté']

# %%
Decision_jury = cdf['Decision jury detailed'].unique()
print(Decision_jury)
# Out:
# ['Mobilité' 'Différé(e)' 'Ajourné' 'Diplomé' 'Admis(e)'
#  'Admis en deuxième année' 'Diplômé ( e )' 'Année Blanche' 'Fail'
#  'Admis en 6ème année' 'Diplômé' 'Diplômée' 'PASS'
#  'Admis en 6ème année avec félicitation du jury'
#  'Admis en M2 avec reliquats' 'Admis en 1ère session mention bien'
#  "Non admis. Doit refaire l'atelier du S10 en Automne 2019/2020" 'CPR'
#  'Admis' 'Admis ( e )' 'Admis en 6ème année  (S10 mobilité en Inde)'
#  'PASS WITH INDULGENCE' 'En attente'
#  'Admis en M2 avec reliquats, Atelier de projet S7 en conditionnel'
#  'Admis en 2ème session mention passable'
#  'Admis en 1ère session mention Très bien' 'mobilité' 'Abandon' 'Pass'
#  'Redoublant' 'Pass with honors' 'Admis en année supérieure'
#  "En mobilité double diplôme à l'Ecole Européenne d'Ingénieurs en Génie des Matériaux Diplomé"
#  "En mobilité double diplôme à l'Ecole Européenne d'Ingénieurs en Génie des Matériaux  Diplomé"
#  'Passage conditionnel (un module à valider N+1 )' 'Admis en M2'
# ...

# %%
Decision_jury = cdf['Decision jury detailed'].value_counts()
Decision_jury.head(50)
# Out:
# ADM                                                              519
# APR                                                              383
# PASS                                                             354
# Admis en deuxième année                                          263
# Admis                                                            256
# Admis ( e )                                                      218
# Admis(e)                                                         199
# Admis en année supérieure                                        175
# Admise                                                           112
# Diplômé (e)                                                      102
# Admis en 6ème année                                               82
# Admis en Licence 2                                                80
# Diplômé ( e )                                                     77
# Admis (e)                                                         70
# ...

# %%
# Remplacements des différentes variations par des valeurs standardisées
decision_replacements = {
    'ABONDON': 'Abandon',
    'Abondan': 'Abandon',
    'Abondon': 'Abandon',
    'ADM': 'Admis(e)',
    'APR': 'Admis(e)',
    'CPR': 'Admis(e)',
    'PASS': 'Admis(e)',
    'Pass': 'Admis(e)',
    'AJ': 'Ajourné',
    'Année blanche': 'Année Blanche',
    'Annéé blanche': 'Année Blanche',
    'Année de césure': 'Année de césure',
    'Autorisé à redoubler': 'Redoublant(e)',
    'Autorisée à redoubler': 'Redoublant(e)',
    'RPP': 'Redoublant(e)',
    'RYR': 'Redoublant(e)',
    'Redoublant ( e )': 'Redoublant(e)',
    'Redoublant ( e)': 'Redoublant(e)',
    'Redoublement': 'Redoublant(e)',
    'Différé' : 'Différé(e)',
    'Différé(e)': 'Différé(e)',
    'Décision Differé (e)': 'Différé(e)',
    'Décision différée': 'Différé(e)',
    'Admis ( e )': 'Admis(e)',
    'Admis':'Admis(e)',
    'Admise' : 'Admis(e)',
    'Admis en M2' : 'Admis en deuxième anné',
    
    'Diplomé': 'Diplômé(e)',
    'Diplômé': 'Diplômé(e)',
    'Diplômé ( e )': 'Diplômé(e)',
    'Diplômé (e)': 'Diplômé(e)',
    'Diplômée': 'Diplômé(e)',

    'Désistement': 'Désistement',
    'En attente': 'En attente',
    'En cours': 'En cours',
    'En mobilité double diplôme à l\'Ecole Européenne d\'Ingénieurs en Génie des Matériaux': 'En mobilité',
    'En mobilité double diplôme à l\'Ecole Européenne d\'Ingénieurs en Génie des Matériaux  Diplomé': 'En mobilité',
    'En mobilité double diplôme à l\'Ecole Européenne d\'Ingénieurs en Génie des Matériaux Diplomé': 'En mobilité',
    'En mobilité double diplôme à l’École Nationale Supérieure d’Electricité et de Mécanique': 'En mobilité',
    'Exclusion': 'Exclusion',
    'FAIL': 'Échec',
    'Fail': 'Échec',
    'Mobilité': 'En mobilité',
    'NPR': 'Non pris en compte',
    'Non admis': 'Non admis',
    'Admis' : 'Admis(e)',
    'PASS WITH HONORS': 'Admis avec mention',
    'PASS WITH INDULGENCE': 'Admis avec indulgence',
    'Pass with honors': 'Admis avec mention',
    'Passage conditionnel (2 modules à valider N+1 )': 'Passage conditionnel',
    'Passage conditionnel (un module à valider N+1 )': 'Passage conditionnel',

    'admis en année supérieure': 'Admis en année supérieure',
    'Admise avec les félicitations du jury' : 'Admis(e) avec les félicitations du jury',
    'Admise avec les félicitations du jury.': 'Admis(e) avec les félicitations du jury',
    'admis en année supérieure avec indulgence du jury': 'Admis en année supérieure',
    'en attente des resultats -\npour une année universitaire': 'En attente',
    'en attente des resultats-\npour une année universitaire': 'En attente',
    'exchange student from ESTACA\n(1 Module non validé)': 'Étudiant en échange',
    'exchange student from ESTACA (PASS)': 'Étudiant en échange',
    'mobilité': 'En mobilité',
    'réorienté': 'Réorienté',
    'Admis (e)' : 'Admis(e)',
    
}

cdf['Decision jury detailed'] = cdf['Decision jury detailed'].replace(decision_replacements)

# %%
Decision_jury = cdf['Decision jury detailed'].value_counts()
Decision_jury.head(50)
# Out:
# Admis(e)                                                         2173
# Diplômé(e)                                                        299
# Admis en deuxième année                                           263
# Admis en année supérieure                                         241
# Admis en 6ème année                                                82
# Admis en Licence 2                                                 80
# Admis avec indulgence                                              56
# Admis en deuxième anné                                             56
# Ajourné                                                            43
# Redoublant(e)                                                      43
# Échec                                                              36
# Admis avec mention                                                 36
# Différé(e)                                                         35
# ...

# %%
cdf['Decision jury detailed'] = cdf.apply(lambda row: 'Diplômé(e)' if row['Decision jury detailed'] == 'Admis(e)' and row['Cycle'] == 'Ingénieur' and row['Niveau'] == '5ème année' else row['Decision jury detailed'], axis=1)
cdf['Decision jury detailed'] = cdf.apply(lambda row: 'Diplomé(e)' if row['Decision jury detailed'] == 'Admis(e)' and row['Cycle'] == 'Master' and row['Niveau'] == '2ème année' else row['Decision jury detailed'], axis=1)
cdf['Decision jury detailed'] = cdf.apply(lambda row: 'Diplomé(e)' if row['Decision jury detailed'] == 'Admis(e)' and row['Cycle'] == 'Architecte' and row['Niveau'] == '6ème année' else row['Decision jury detailed'], axis=1)

# %%
Decision_jury = cdf['Decision jury detailed'].value_counts()
Decision_jury.head(50)
# Out:
# Admis(e)                                                         1914
# Diplômé(e)                                                        331
# Admis en deuxième année                                           263
# Admis en année supérieure                                         241
# Diplomé(e)                                                        227
# Admis en 6ème année                                                82
# Admis en Licence 2                                                 80
# Admis avec indulgence                                              56
# Admis en deuxième anné                                             56
# Redoublant(e)                                                      43
# Ajourné                                                            43
# Échec                                                              36
# Admis avec mention                                                 36
# ...

# %%
cdf['Diplômés'] = cdf.apply(lambda row: 'Oui' if row['Decision jury'] == 'Admis' and row['Cycle'] == 'Ingénieur' and row['Niveau'] == '5ème année' else 'Non', axis=1)
cdf['Diplômés'] = cdf.apply(lambda row: 'Oui' if row['Decision jury'] == 'Admis' and row['Cycle'] == 'Master' and row['Niveau'] == '2ème année' else 'Non', axis=1)
cdf['Diplômés'] = cdf.apply(lambda row: 'Oui' if row['Decision jury'] == 'Admis' and row['Cycle'] == 'Architect' and row['Niveau'] == '6ème année' else 'Non', axis=1)
cdf['Diplômés'] = cdf.apply(lambda row: 'Oui' if row['Decision jury'] == 'Admis' and row['Cycle'] == 'Licence' and row['Niveau'] == '3ème année' else 'Non', axis=1)
cdf['Diplômés'] = cdf.apply(lambda row: 'Oui' if row['Decision jury'] == 'Admis' and row['Cycle'] == 'Medecine' and row['Niveau'] == '7ème année' else 'Non', axis=1)
cdf.loc[cdf['Decision jury'] == 'Admis', 'Diplômés'].head(20)
# Out:
# 1     Non
# 3     Non
# 4     Non
# 5     Non
# 6     Non
# 7     Non
# 8     Non
# 9     Non
# 12    Non
# 13    Non
# 14    Non
# 15    Non
# 16    Non
# 17    Non
# 18    Non
# 19    Non
# 20    Non
# 21    Non
# 22    Non
# 23    Non
# Name: Diplômés, dtype: object

# %%
cdf['Diplômés'] = 'Non'
cdf.loc[(cdf['Decision jury'] == 'Admis') & (cdf['Cycle'] == 'Ingénieur') & (cdf['Niveau'] == '5ème année'), 'Diplômés'] = 'Oui'
cdf.loc[(cdf['Decision jury'] == 'Admis') & (cdf['Cycle'] == 'Master') & (cdf['Niveau'] == '2ème année'), 'Diplômés'] = 'Oui'
cdf.loc[(cdf['Decision jury'] == 'Admis') & (cdf['Cycle'] == 'Architect') & (cdf['Niveau'] == '6ème année'), 'Diplômés'] = 'Oui'
cdf.loc[(cdf['Decision jury'] == 'Admis') & (cdf['Cycle'] == 'Licence') & (cdf['Niveau'] == '3ème année'), 'Diplômés'] = 'Oui'
cdf.loc[(cdf['Decision jury'] == 'Admis') & (cdf['Cycle'] == 'Medecine') & (cdf['Niveau'] == '7ème année'), 'Diplômés'] = 'Oui'
cdf.loc[cdf['Decision jury'] == 'Admis', 'Diplômés'].head(20)
# Out:
# 1     Oui
# 3     Oui
# 4     Oui
# 5     Non
# 6     Oui
# 7     Oui
# 8     Non
# 9     Oui
# 12    Non
# 13    Oui
# 14    Non
# 15    Non
# 16    Non
# 17    Non
# 18    Non
# 19    Non
# 20    Non
# 21    Oui
# 22    Non
# 23    Non
# Name: Diplômés, dtype: object

# %%
Decision_jury = cdf['Diplômés'].value_counts()
Decision_jury.head()
# Out:
# Non    3304
# Oui     703
# Name: Diplômés, dtype: int64

# %%
Decision_jury = cdf['Ville'].unique()
print(Decision_jury)
# Out:
# [nan 'Rabat' 'RABAT' 'Casablanca' 'Fès' 'TANGER' 'KENITRA' 'Salé'
#  'Kénitra' 'El Jadida' 'Taza' 'Kenitra' 'Agadir' 'Sidi Kacem' 'Marrakech'
#  'Khémisset' 'Temara' 'Larache' 'Oujda' 'Sala El Jadida' 'Tanger' 'MEKNES'
#  'Ouezzane' 'SALE' 'Fkih Ben Salah' 'Tetouan' 'HARHOURA' 'AL HOCEIMA'
#  'Khemisset' 'FES' 'MARRAKECH' 'ESSAOUIRA' 'TEMARA' 'Taounate' 'EL JADIDA'
#  'SALA AL JADIDA' 'Sala Al Jadida' 'KHEMISSET' 'tanger' 'Meknès' 'Meknes'
#  'AGADIR' 'Harhoura' 'Mohammédia' 'Beni Mellal' 'settat' 'MIDELT' 'temara'
#  'sala eljadida' 'Mohammedia' 'salé' 'Nador' 'fes' 'tetouan'
#  'el kelaa des sraghna' 'casablanca' 'azrou' 'khemisset' 'Settat'
#  'MOHAMMEDIA' 'rabat' 'BENI MELLEL' 'Safi' 'el jadida' 'Midelt' 'Sefrou'
#  'Alhoceima' 'Abidjan (Côte d´Ivoire)' 'BENI MELLAL' 'CASABLANCA' 'Témara'
#  'Fes' 'TETOUAN' 'OUEZZANE' 'Guercif' 'sefrou' 'SOUKEL ARBAA DU GHARB'
#  'kenitra' 'Cameroun / batoussam' 'beni mellal' 'Al hoceima' 'Berkane'
# ...

# %%
city_normalization = {
    'RABAT': 'Rabat',
    'TANGER': 'Tanger',
    'KENITRA': 'Kénitra',
    'Kenitra': 'Kénitra',
    'Khémisset': 'Khémisset',
    'Temara': 'Temara',
    'Larache': 'Larache',
    'Oujda': 'Oujda',
    'MEKNES': 'Meknès',
    'SALE': 'Salé',
    'Fkih Ben Salah': 'Fkih Ben Salah',
    'Tetouan': 'Tétouan',
    'HARHOURA': 'Harhoura',
    'AL HOCEIMA': 'Al Hoceima',
    'Khemisset': 'Khemisset',
    'FES': 'Fès',
    'MARRAKECH': 'Marrakech',
    'ESSAOUIRA': 'Essaouira',
    'TEMARA': 'Temara',
    'EL JADIDA': 'El Jadida',
    'SALA AL JADIDA': 'Sala Al Jadida',
    'Sala Al Jadida': 'Sala Al Jadida',
    'KHEMISSET': 'Khemisset',
    'tanger': 'Tanger',
    'Meknès': 'Meknès',
    'Meknes': 'Meknès',
    'AGADIR': 'Agadir',
    'Mohammédia': 'Mohammedia',
    'settat': 'Settat',
    'MIDELT': 'Midelt',
    'temara': 'Temara',
    'sala eljadida': 'Sala El Jadida',
    'salé': 'Salé',
    'Nador': 'Nador',
    'fes': 'Fès',
    'tetouan': 'Tétouan',
    'el kelaa des sraghna': 'El Kelaa des Sraghna',
    'casablanca': 'Casablanca',
    'azrou': 'Azrou',
    'khemisset': 'Khemisset',
    'Settat': 'Settat',
    'MOHAMMEDIA': 'Mohammedia',
    'rabat': 'Rabat',
    'BENI MELLEL': 'Beni Mellal',
    'Safi': 'Safi',
    'el jadida': 'El Jadida',
    'Midelt': 'Midelt',
    'Sefrou': 'Sefrou',
    'Alhoceima': 'Al Hoceima',
    'Abidjan (Côte d´Ivoire)': 'Abidjan',
    'BENI MELLAL': 'Beni Mellal',
    'CASABLANCA': 'Casablanca',
    'Témara': 'Témara',
    'Fes': 'Fès',
    'TETOUAN': 'Tétouan',
    'OUEZZANE': 'Ouezzane',
    'Guercif': 'Guercif',
    'sefrou': 'Sefrou',
    'SOUKEL ARBAA DU GHARB': 'Souk El Arbaa',
    'kenitra': 'Kénitra',
    'Cameroun / batoussam': 'Cameroun',
    'beni mellal': 'Beni Mellal',
    'Al hoceima': 'Al Hoceima',
    'Berkane': 'Berkane',
    'Berrechid': 'Berrechid',
    'Khénifra': 'Khénifra',
    'fès': 'Fès',
    'safi': 'Safi',
    'TAOUNATE': 'Taounate',
    'AL Hoceima': 'Al Hoceima',
    'FQIH BEN SALAH': 'Fkih Ben Salah',
    'Tétouan': 'Tétouan',
    'Sidi Bennour': 'Sidi Bennour',
    'Errachidia': 'Errachidia',
    'KHENIFRA': 'Khénifra',
    'OUJDA': 'Oujda',
    'meknes': 'Meknès',
    'Mohamedia': 'Mohammedia',
    'Ben Guerir': 'Ben Guerir',
    'kénitra': 'Kénitra',
    'Harhoura-Témara': 'Harhoura-Témara',
    'sala el jadida': 'Sala El Jadida',
    'Kasba Tadla': 'Kasba Tadla',
    'Laayoune': 'Laayoune',
    'DEMNATE': 'Demnate',
    'Tiflet': 'Tiflet',
    'Khouribga': 'Khouribga',
    'AL-Khobar': 'Al-Khobar',
    'SOUK EL ARBAA': 'Souk El Arbaa',
    'Sidi Slimane': 'Sidi Slimane',
    'Al Hoceïma': 'Al Hoceima',
    'Taroudant': 'Taroudant',
    'FKIH BEN SALAH': 'Fkih Ben Salah',
    'Fkih Ben Saleh': 'Fkih Ben Salah',
    'Béni mellal': 'Beni Mellal',
    'AZEMMOUR': 'Azemmour',
    'Asilah': 'Asilah',
    'BEJAAD': 'Bejaad',
    'SAFI': 'Safi',
    'BENSLIMANE': 'Benslimane',
    'Azrou': 'Azrou',
    'El hajeb': 'El Hajeb',
    'Tinghir': 'Tinghir',
    'Essaouira': 'Essaouira',
    'oujda': 'Oujda',
    'Taourirt': 'Taourirt',
    'Chefchaouen': 'Chefchaouen',
    'Ouarzazate': 'Ouarzazate',
    'Benguerir': 'Ben Guerir',
    'Kser el Kebir': 'Ksar El Kebir',
    'Bruxelles': 'Brussels',
    'Tiznit': 'Tiznit',
    'Cameroun': 'Cameroon',
    'ELJADIDA': 'El Jadida',
    'FNIDEQ': 'Fnideq',
    'KELAA DES SRAGHNA': 'Kelaa Des Sraghna',
    'INEZGANE': 'Inezgane',
    'Sale': 'Salé',
    'Sala Aljadida': 'Sala Al Jadida',
    'Toulouse': 'Toulouse',
    'Autre': 'Other',
    'Azilal': 'Azilal',
    'El jadida': 'El Jadida',
    'Skhirat': 'Skhirat',
    'Oued Zem': 'Oued Zem',
    'SALÉ': 'Salé',
    'Ksar El Kebir': 'Ksar El Kebir',
    'Fés': 'Fez',
    'inzegane': 'Inezgane',
    'SALA EL JADIDA': 'Sala El Jadida',
    'cormery': 'Cormery',
    'marrakech': 'Marrakech',
    'ksar el kebir': 'Ksar El Kebir',
    'KSAR EL KEBIR': 'Ksar El Kebir',
    'Tamesna': 'Tamesna',
    'Ksar El Kbir': 'Ksar El Kebir',
    'sale': 'Salé',
    'fnideq': 'Fnideq',
    'kelaa des sraghnaa': 'Kelaa Des Sraghna',
    'boujdour': 'Boujdour',
    'bejaad': 'Bejaad',
    'Inezgane': 'Inezgane',
    'Sidi ifni': 'Sidi Ifni',
    'ECHENEVEX': 'Echenevex',
    'Caire Egypt': 'Cairo, Egypt',
    'témara': 'Témara',
    'KELAAT M´GOUNA': 'Kelaat M\'Gouna',
    'EL Jadida': 'El Jadida',
    'agadir': 'Agadir',
    'mohammédia': 'Mohammedia',
    'ouled teima': 'Ouled Teima',
    'el hajeb': 'El Hajeb',
    'tiznit': 'Tiznit',
    'khénifra': 'Khenifra',
    'nador': 'Nador',
    'tétouan': 'Tetouan',
    'errachidia': 'Errachidia',
    'TAZA': 'Taza',
    'midelt': 'Midelt',
    'Sidi kacem': 'Sidi Kacem',
    'Sala el jadida': 'Sala El Jadida',
    'Sidi slimane': 'Sidi Slimane',
    'Arfoud': 'Arfoud',
    'Beni mellal': 'Beni Mellal',
    'Youssoufia': 'Youssoufia',
    'Laâyoune': 'Laayoune',
    'Ouled teima': 'Ouled Teima',
    'Dakhla': 'Dakhla',
    'Ksar el kebir': 'Ksar El Kebir',
    'Al hoceïma': 'Al Hoceima',
    'Berréchid': 'Berrechid',
    'Bouznika': 'Bouznika',
    'Azemmour': 'Azemmour',
    'Chichaoua': 'Chichaoua',
    'OUARZAZATE': 'Ouarzazate',
    'Martil': 'Martil',
    'El kelaa des sraghna': 'El Kelaa Des Sraghna',
    'Inzegane': 'Inezgane',
    'Fkih ben salah': 'Fkih Ben Salah',
    'Ouagadougou': 'Ouagadougou',
    'Souk es sebt': 'Souk Es Sebt',
    'Ain atiq': 'Ain Atiq',
    'Ben ahmed': 'Ben Ahmed',
    'Libreville': 'Libreville',
    'tchad': 'Chad',
    'AIN BENI MATHAR': 'Ain Beni Mathar',
    'Sala al jadida': 'Sala Al Jadida',
    'Saïdia': 'Saïdia',
    'MDIQ': 'M\'Diq',
    'Assilah': 'Assilah',
    'SALA ALJADIDA': 'Sala Al Jadida',
    'BERRECHID': 'Berrechid',
    'Brazzaville': 'Brazzaville',
    'Casabanca': 'Casablanca',
    'Mèknes': 'Meknes',
    'ERRACHIDIA': 'Errachidia',
    'Afourer': 'Afourer',
    'SIDI KACEM': 'Sidi Kacem',
    'SETTAT': 'Settat',
    'NADOR': 'Nador',
    'Sidi sliman': 'Sidi Slimane',
    'Fnidaq': 'Fnideq',
    'Mohammedai': 'Mohammedia',
    'Ain aouda': 'Ain Aouda',
    'Ifrane': 'Ifrane',
    'Paris': 'Paris',
    'Ouazzane': 'Ouazzane',
    'KHOURIBGA': 'Khouribga',
    'eljadida': 'El Jadida',
    'M´diq': 'M\'Diq',
    'Romani': 'Romani',
    'Sidi bennour': 'Sidi Bennour',
    'Souk Al arbaa': 'Souk Al Arbaa',
    'Oued zem': 'Oued Zem',
    'Riyad': 'Riyadh',
    'Khenifra': 'Khenifra',
    'TAMESNA': 'Tamesna',
    'laayoune': 'Laayoune',
    'LARACHE': 'Larache',
    '10100': '10100',
    'BERKANE': 'Berkane',
    'Oued-zem': 'Oued Zem',
    'CASABLNACA': 'Casablanca',
    'SALA JADIDA': 'Sala Al Jadida',
    'Es-smara': 'Es-Semara',
    '11080': '11080',
    'Afourer AZILAL': 'Afourer, Azilal',
    'Mdiq': 'M\'Diq',
    'Benslimane': 'Benslimane',
    'AIT MELLOUL': 'Ait Melloul',
    'Abidjan': 'Abidjan',
    'Ain Aouda': 'Ain Aouda',
    'CHICHAOUA': 'Chichaoua',
    'KSAR EL KEBIR LARACHE': 'Ksar El Kebir, Larache',
    'EL HAJEB': 'El Hajeb',
    'Ait melloul': 'Ait Melloul',
    'Champs-sur-marne': 'Champs-sur-Marne',
    'Rouen': 'Rouen',
    'Jerada': 'Jerada',
    'Guelmim': 'Guelmim',
    'TINGHIR': 'Tinghir',
    'Bejaad': 'Bejaad',
    'TAnger': 'Tangier',
    'Dakar': 'Dakar',
    'Monastir': 'Monastir',
    'AZROU': 'Azrou',
    'al hoceima': 'Al Hoceima',
    'GONNEBEK': 'Gonnebek',
    'OUAZZANE': 'Ouazzane',
    'Khemisset':'Khémisset'
}

cdf['Ville'] = cdf['Ville'].replace(city_normalization)

city_normalization = cdf['Ville'].value_counts()
city_normalization.head(60)
# Out:
# Rabat                   1055
# Salé                     341
# Temara                   259
# Kénitra                  251
# Casablanca               245
# Tanger                   153
# Marrakech                153
# Meknès                   150
# Fès                      131
# Tétouan                  130
# Agadir                   100
# Sala El Jadida            95
# El Jadida                 80
# Oujda                     63
# Mohammedia                52
# Beni Mellal               47
# Settat                    26
# Nador                     26
# Taza                      24
# Safi                      24
# Larache                   22
# Laayoune                  22
# Sala Al Jadida            22
# Khouribga                 19
# Berkane                   18
# Khémisset                 17
# Témara                    17
# Midelt                    16
# Ksar El Kebir             13
# Errachidia                11
# Sefrou                    11
# Al Hoceima                11
# ...

# %%
cdf['Nb absences'] = cdf['Nb absences'].fillna(0)
cdf['Nb absences'].value_counts()
# Out:
# 0.0      1854
# 2.0        97
# 6.0        90
# 7.0        82
# 13.0       75
#          ...
# 116.0       1
# 127.0       1
# 130.0       1
# 70.0        1
# 118.0       1
# Name: Nb absences, Length: 144, dtype: int64

# %%
cdf['Boursier'] = cdf['Boursier'].fillna('Non')

# %%
cdf.isnull().sum()
# Out:
# N°                          0
# Nom étudiant                1
# Niveau                      1
# Cycle                       0
# Filière                     0
# Etablissement               0
# College                     0
# Moyenne S1                 71
# Moyenne S2                 59
# Moyenne                    54
# Decision jury detailed      0
# Tranche                   281
# Sexe                        0
# Nationalité                73
# Date de naissance          69
# Mention bac               132
# Moyenne bac               896
# Année bac                  68
# Option bac                 90
# Série bac                  90
# Domaine bac                90
# Niveau accès UIR          151
# Date inscription UIR       26
# Boursier                    0
# Decision jury               0
# CSP Père                  873
# CSP Mère                  884
# Lycée origine             333
# Système d'études          333
# Région                    134
# Ville                     134
# ...

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4007 entries, 0 to 4006
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   N°                      4007 non-null   int64
#  1   Nom étudiant            4006 non-null   object
#  2   Niveau                  4006 non-null   object
#  3   Cycle                   4007 non-null   object
#  4   Filière                 4007 non-null   object
#  5   Etablissement           4007 non-null   object
#  6   College                 4007 non-null   object
#  7   Moyenne S1              3936 non-null   object
#  8   Moyenne S2              3948 non-null   object
#  9   Moyenne                 3953 non-null   object
#  10  Decision jury detailed  4007 non-null   object
#  11  Tranche                 3726 non-null   object
#  12  Sexe                    4007 non-null   object
#  13  Nationalité             3934 non-null   object
# ...

# %%
def convert_to_float(x):
    if x == 'ABS' or x == 'Soutenance reportée':
        return 0.0
    else:
        return float(x)

# Appliquer la fonction de conversion aux colonnes de moyennes
cdf['Moyenne S1'] = cdf['Moyenne S1'].apply(convert_to_float)
cdf['Moyenne S2'] = cdf['Moyenne S2'].apply(convert_to_float)
cdf['Moyenne'] = cdf['Moyenne'].apply(convert_to_float)

# %%
import re
cdf['Moyenne bac'] = cdf['Moyenne bac'].str.replace(r'[^0-9\.]', '.', regex=True)
cdf['Moyenne bac'] = cdf['Moyenne bac'].astype(float)

# %%
cdf['Date de naissance'] = pd.to_datetime(cdf['Date de naissance'])

# %%
cdf['Nb absences'] = cdf['Nb absences'].astype(int)

# %%
cdf.dtypes
# Out:
# N°                                 int64
# Nom étudiant                      object
# Niveau                            object
# Cycle                             object
# Filière                           object
# Etablissement                     object
# College                           object
# Moyenne S1                       float64
# Moyenne S2                       float64
# Moyenne                          float64
# Decision jury detailed            object
# Tranche                           object
# Sexe                              object
# Nationalité                       object
# Date de naissance         datetime64[ns]
# Mention bac                       object
# Moyenne bac                      float64
# Année bac                         object
# Option bac                        object
# Série bac                         object
# Domaine bac                       object
# Niveau accès UIR                  object
# Date inscription UIR              object
# ...

# %%
cdf.to_csv('UIR_DATA_WHEREHOUSE.csv', index=False)
